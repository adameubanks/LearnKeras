# %% [markdown]
# **First things first, we need to import the nessecary dependencies.**

# %%
import keras #ML Library
import numpy as np #Mathematics Library
import pandas as pd #Data-handling Library
import matplotlib.pyplot as plt #Used to graph our results

# %% [markdown]
# **Next, we need to import our data. You can do this many ways. The easiet is to upload the csv directly to drive on the 'files' section of the side bar. However, when we reset the runtime, this file will delete. The csv can also be loaded directly from github or from your drive if you have uploaded the csv.**

# %%
#If you want to import from Drive
from google.colab import drive
drive.mount('/content/drive')
df=pd.read_csv('drive/My Drive/Courses/LearnML/1.LinearRegression/IowaHousingPrices.csv')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# **Now that we've loaded the csv into pandas, we will separate the two columns of features we want to use. squareFeet will be our x value and salePrice will be our y value.**

# %%
squareFeet = df[['SquareFeet']].values #x value
salePrice = df[['SalePrice']].values #y value

# %% [markdown]
# **Here we create the model and fit it to our square feet and sale price. Adjust the epochs, learning rate, and batch size for the outcome that is the fastest and most accurate.**

# %%
model = keras.Sequential()
model.add(keras.layers.Dense(1, input_shape=(1,)))
model.compile(keras.optimizers.Adam(lr=1), 'mean_squared_error')

model.fit(squareFeet,salePrice, epochs=30, batch_size=10)
# Out:
# Epoch 1/30
# 1460/1460 [==============================] - 0s 200us/step - loss: 14058974809.4247
# Epoch 2/30
# 1460/1460 [==============================] - 0s 90us/step - loss: 3278140529.0959
# Epoch 3/30
# 1460/1460 [==============================] - 0s 84us/step - loss: 3188736134.5753
# Epoch 4/30
# 1460/1460 [==============================] - 0s 83us/step - loss: 3193606640.4384
# Epoch 5/30
# 1460/1460 [==============================] - 0s 90us/step - loss: 3198966714.5205
# Epoch 6/30
# 1460/1460 [==============================] - 0s 87us/step - loss: 3205906639.1233
# Epoch 7/30
# 1460/1460 [==============================] - 0s 95us/step - loss: 3198352352.2192
# Epoch 8/30
# 1460/1460 [==============================] - 0s 94us/step - loss: 3192377074.6301
# Epoch 9/30
# 1460/1460 [==============================] - 0s 86us/step - loss: 3176562529.9726
# Epoch 10/30
# 1460/1460 [==============================] - 0s 85us/step - loss: 3215286368.0000
# Epoch 11/30
# 1460/1460 [==============================] - 0s 93us/step - loss: 3181153295.1233
# Epoch 12/30
# 1460/1460 [==============================] - 0s 87us/step - loss: 3186474429.5890
# Epoch 13/30
# 1460/1460 [==============================] - 0s 86us/step - loss: 3201656951.2329
# Epoch 14/30
# 1460/1460 [==============================] - 0s 97us/step - loss: 3200280193.9726
# Epoch 15/30
# 1460/1460 [==============================] - 0s 90us/step - loss: 3190375292.0548
# Epoch 16/30
# 1460/1460 [==============================] - 0s 89us/step - loss: 3205840242.1918
# Epoch 17/30
# 1460/1460 [==============================] - 0s 90us/step - loss: 3178732179.9452
# Epoch 18/30
# 1460/1460 [==============================] - 0s 92us/step - loss: 3216536753.0959
# Epoch 19/30
# 1460/1460 [==============================] - 0s 89us/step - loss: 3209540834.6301
# Epoch 20/30
# 1460/1460 [==============================] - 0s 88us/step - loss: 3188408138.7397
# Epoch 21/30
# 1460/1460 [==============================] - 0s 89us/step - loss: 3209110496.2192
# Epoch 22/30
# 1460/1460 [==============================] - 0s 89us/step - loss: 3214394935.2329
# Epoch 23/30
# 1460/1460 [==============================] - 0s 90us/step - loss: 3197790638.9041
# Epoch 24/30
# 1460/1460 [==============================] - 0s 99us/step - loss: 3198525930.9589
# Epoch 25/30
# 1460/1460 [==============================] - 0s 89us/step - loss: 3197273090.6301
# Epoch 26/30
# 1460/1460 [==============================] - 0s 95us/step - loss: 3203376289.5342
# Epoch 27/30
# 1460/1460 [==============================] - 0s 87us/step - loss: 3208302739.7260
# Epoch 28/30
# 1460/1460 [==============================] - 0s 88us/step - loss: 3190572835.0685
# Epoch 29/30
# 1460/1460 [==============================] - 0s 91us/step - loss: 3187649560.3288
# Epoch 30/30
# 1460/1460 [==============================] - 0s 88us/step - loss: 3184815412.3836

# %% [markdown]
# **Now that our model is trained, we need to use matplotlib to plot our data and the line that we have created so that we can see how accurate it is.**

# %%
#Plot datapoints
df.plot(kind='scatter',
       x='SquareFeet',
       y='SalePrice', title='Housing Prices and Square Footage of Iowa Homes')


y_pred = model.predict(squareFeet) #The predicted housing price based on square feet

#Plot the linear regression line
plt.plot(squareFeet, y_pred, color='red')

# %% [markdown]
# **Finally, if we want to predict the price of a new house, we use the following code. We set the square footage equale to newSF and the output is the expected price in US dollars**

# %%
newSF = 2000
print(model.predict([newSF]))
# Out:
# [[241790.06]]
